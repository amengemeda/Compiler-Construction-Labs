# %% [markdown]
# <a href="https://colab.research.google.com/github/amengemeda/Compiler-Construction-Labs/blob/main/Compiler_Construction_Labs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Group Members
# Amen Gemeda - 122475
#
# Cyprian Kyalo - 121457
#
# Maryann Gitonga - 097770
#
# Margaret Mugo - 120791
#
# Georgina Njoroge - 119742

# %% [markdown]
# # Lab 1
# Give brief descriptions of the following tools:
#
# Flex, Bison, Lex, Yacc
#
# The description should have: 3-5 lines definition, diagram and code snippet

# %% [markdown]
# ## Lex
#
# A Lex is a program generator designed for lexical processing of character input streams.
#
# It accepts a high-level, problem oriented specification for character string matching, and produces a program in a general purpose language which recognizes regular expressions.
#
# The regular expressions are specified by the user in the source specifications given to Lex and the Lex written code recognizes these expressions in an input stream and partitions the input stream into strings matching the expressions.
#
# At the boundaries between strings program
#
# The lexical analyzer creates a program in the Lex language and the Lex compiler runs the program and produces a C program.
#
# The C compiler runs the C program and produces an object program which is the lexical analyzer that transforms an input stream into a sequence of tokens.
#
#
# ![lex.PNG](data:image/png;base64,...)
#
#
# Below is an example of a Lex program which recognizes the strings of numbers in the input and prints them out:
#
# ```
# /*** Definition section: declares variables, constants and imports ***/
#
# %{
# /* C code to be copied verbatim */
# #include <stdio.h>
# %}
#
# %%
# /*** Rules section: describes various patterns (regular expressions and actions that the lexical analyzer should take when a pattern matches
# a lexeme ***/
#
#     /* [0-9]+ matches a string of one or more digits */
# [0-9]+  {
#             /* yytext is a string containing the matched text. */
#             printf("Saw an integer: %s\n", yytext);
#         }
#
# .|\n    {   /* Ignore all other characters. */   }
#
# %%
# /*** Auxiliary functions section: defines functions that are required by actions to execute ***/
#
# int main(void)
# {
#     /* Call the lexer, then quit. */
#     yylex();
#     return 0;
# }
# ```

# %% [markdown]
# ## Flex
# Fast Lexical Analyzer Generator(Flex) is a tool for generating programs lexical analyzers, that perform pattern-matching on text.
#
# It is used in writing compilers in conjuction with GNU Bison. It is a rewrite of the Unix Lex tool, although the two implementations do not share any code. Flex is about two times faster than Lex. It is also more flexible.
#
# Flex works similarly to Lex. This is shown in the image below:
#
# ![image.png](data:image/png;base64,...)
#
# The program structure has 3 sections; definition, rules and user code. Definitions include declarations of constant, variable and regular definitions. Rules include rules of pattern action form. User code contains C statements and additional functions.
#
#
# Below is a code snippet of Flex:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##*Bison*

# %% [markdown]
# Bison is a general-purpose generator that converts an annotated context-free grammar into a deterministic Left Right(LR) parser or generalized LR parser applying Look Ahead LR parser. Once one becomes proficient in Bison one can be able to develop language parser.
#
# Bison is upward compatible with Yacc; properly written Yacc grammars are supposed to work with Bison
#
# The Bison parser is a bottom-up parser. It tries, by shifts and reductions, to reduce the entire input down to a single grouping whose symbol is the grammar's start-symbol.
#
# ![image.png](data:image/png;base64,...)
#
#
# One might be able to create a C scanner and then compiling this output with a C++ compiler to allow compiling though in this case the scanner is written in C++ code
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Yacc

# %% [markdown]
# Yacc (Yet Another Compiler Compiler) is a tool that is used to generate a parser. It translates a given Context Free Grammar (CFG) specifications into a C implementation of a corresponding push down automaton (a finite state machine with a stack). <br><br>
# Yacc is used to produce the source code of the syntactic analyzer of the language produced by LALR(1) (LookAhead, Left-to-right, Rightmost derivation producer with 1 lookahead token) grammar. <br><br>
# The input of YACC is the rule or grammar, and the output is a C program.<br><br>
# For instance, if we have a file **_translate.y_** that consists of Yacc specification, we can convert the file into a C file ***y.tab.c***. We then compile ***y.tab.c*** to get the desired object program ***a.out*** as shown in the diagram below.<br><br>![image.png](data:image/png;base64,...)

# %% [markdown]
#  Below is a code snippet of Yacc:<br><br>:
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Lab 2
# A) Using any TWO examples, show the conversion of NFA to DFA.

# %% [markdown]
# ![NFAtoDFA.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# B) Using the material on E-Learning, show how to use Flex and Bison when building a
# simple lexical analyzer.

# %% [markdown]
# Flex operates as explained in Lab 1 above.
# The scanner generated from the flex input file below checks whether the characters in provided input is a lowercase vowel or not and counts the vowels.
# The rules section in the flex input file has 3 rules:
#
#     - [aeiou] ; Matches with all lowercase vowels
#     - .       ; Matches with any character except newline
#     - \n      ; Does not take input after enter

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Output after running the flex input file is illustrated in the image below:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Lab 3
# Please refer to Lab 2 above to see the flex input file

# %% [markdown]
# # Lab 4
#
# 1.**Using an example or illustration, explain what is predictive parsing?**
#
# ![image.png](data:image/png;base64,...)
#
# Predictive parsing is a type of recursive descent parsing which can predict which production rule is to be used to replace a stream of characters without backtracking. Such a parser uses a look-ahead pointer which points to the next input symbols to help it in the prediction of the most correct production to pick based on what the next symbol is. To achieve non-backtracking, the predictive parser only accepts LL(k) grammar which is displayed using an LL(k) table or a parsing table.
#
# It utilizes a stack and a parsing table to parse the input stream and generate a parse tree. The stack and the input contain a $ to denote the end of the input or an empty stack. The parser refers to the parsing table to make a decision on the input and stack element combination.
# <br><br>
# 2.**As an extension to question 1,**<br>
# (a) **What is LL (1) parsing?**<br>
# LL(1) parsing is a predictive type of top-down parsing for a restricted context-free language which parses the input stream from left to right, performing the leftmost derivation of the sentence. Such a parser uses 1 token of lookahead when parsing.
#
# (b) **Why do we get the First () and Follow () i.e. what do these two functions Really Represent?**
#
# First() and Follow() are used by parsing algorithms to find out which production to use for parsing a string, allowing the parser to properly apply needed production rules at the correct position.
# First() represents a function that returns a set of terminals that begin the string(s) being derived from a particular production rule. Follow() represents the set of terminals that can be displayed(follow) to the right of a non-terminal in the process of expansion of a string containing that non-terminal. These functions save the parser from the downside of backtracking.
# <br><br>
# 3.**Unique attributes for top-down parsing**:<br>
#   i) The left-most prediction is usually processed first.<br>
#   ii) It builds/constructs the parse tree from the root node gradually moving down to the leaf nodes.<br>
#   iii) It rederives the word starting at the input symbol.

# %% [markdown]
# # Lab 5
#
# 1. This phase of compiler construction takes input from the lexical analyzer. The input is in form of tokens. Syntax analysis involves checking whether the stream of tokens can be generated from the grammar used for the source language. If the token is grammatically correct, the parser produces a parse tree for the string. On the other hand, if the token is grammatically incorrect, the parser returns a syntax error. The parse trees are passed as input to the semantic analyzers.
#
# The diagram below illustrates this process.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Flex and Bison(Yacc) can be combined to develop a syntax analyzer. Flex, performs lexical analysis. It takes a stream of characters as input and produces tokens as output. Yacc uses the tokens as input. It uses grammar rules to analyze the tokens and create a syntax tree.
#
# The image below illustrates a summary on how the two are combined.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The simple syntax analyzer illustrated in the code snippets below is implemented using Flex and Bison. The syntax analyzer counts words and returns the number of words in the input.
#
# The flex scanner returns various tokens including: upper, lower, word, newline and character. This is specified in the rules section.
#
# The snippets below illustrate the scanner code.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Bison is used to implement the parser. The parser calls the scanner in the first section. The scanner returns token values as specified in the rules. The subroutines are implemented in the parser rather than in the scanner.
#
# The parser code is illustrated in the image below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Lab 6
#
# **Question:**
# Do a quick summary of the front end.
# In this activity, use a string example e.g. x+2*y to show the work
# of the various phases of the front end.
#
# **Answer:**
#
# Input string: A = B + C * 2
#
# **Lexical Analaysis**
# <br>
# Token stream: <A,id>, <=, assign>, <B, id>, <+, op>, <C, id>, <*, op>, <2, int>
#
# **Parsing**
# <br>
# `expr ? expr assign expr | expr op expr | num | id`
#
# `assign ? =`
#
# `op ?  / | * | + | -`

# %% [markdown]
# ![WhatsApp Image 2022-11-06 at 6.04.18 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Parse Tree**
#
# ![IMG_20221107_090530_771.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Syntax Tree**
#
# ![IMG_20221107_090530_772.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Parse Tree**
# <br>
# ![WhatsApp Image 2022-11-06 at 6.22.25 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Syntax Tree**
# <br>
# ![WhatsApp Image 2022-11-06 at 6.22.33 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **First() and Follow()**
# ![CamScanner 11-03-2022 22.28_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **LL(1) Parsing Table**
# ![CamScanner 11-03-2022 22.28_1.jpg](data:image/jpeg;base64,...)
